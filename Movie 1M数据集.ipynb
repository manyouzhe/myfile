# %%
import pandas as pd

# %%
unames =['user_id', 'gender','age','occupation','zip']

# %%
users=pd.read_table('G:/learn/JupyterCode/pydata-book/ch02/movielens/users.dat',sep='::',header=None,names=unames)
# Out:
# E:\ruanjian\Anaconda2\envs\gl-env\lib\site-packages\ipykernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
print(len(users))
users.head()
# Out:
# 6040
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
rnames=['user_id','movie_id','rating','timestamp']
ratings=pd.read_table('G:/learn/JupyterCode/pydata-book/ch02/movielens/ratings.dat',\
                      sep='::',header=None,names=rnames)
# Out:
# E:\ruanjian\Anaconda2\envs\gl-env\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
mnames=['movie_id','title','genres']
movies=pd.read_table('G:/learn/JupyterCode/pydata-book/ch02/movielens/movies.dat',\
                      sep='::',header=None,names=mnames)
# Out:
# E:\ruanjian\Anaconda2\envs\gl-env\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app

# %%
ratings[:5]
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
movies[:5]
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
ratings
# Out:
#          user_id  movie_id  rating  timestamp
# 0              1      1193       5  978300760
# 1              1       661       3  978302109
# 2              1       914       3  978301968
# 3              1      3408       4  978300275
# 4              1      2355       5  978824291
# 5              1      1197       3  978302268
# 6              1      1287       5  978302039
# 7              1      2804       5  978300719
# 8              1       594       4  978302268
# 9              1       919       4  978301368
# 10             1       595       5  978824268
# 11             1       938       4  978301752
# 12             1      2398       4  978302281
# 13             1      2918       4  978302124
# 14             1      1035       5  978301753
# 15             1      2791       4  978302188
# 16             1      2687       3  978824268
# 17             1      2018       4  978301777
# 18             1      3105       5  978301713
# ...

# %%
data=pd.merge(pd.merge(ratings,users),movies) #合并数据

# %%
data
# Out:
#          user_id  movie_id  rating   timestamp gender  age  occupation    zip  \
# 0              1      1193       5   978300760      F    1          10  48067
# 1              2      1193       5   978298413      M   56          16  70072
# 2             12      1193       4   978220179      M   25          12  32793
# 3             15      1193       4   978199279      M   25           7  22903
# 4             17      1193       5   978158471      M   50           1  95350
# 5             18      1193       4   978156168      F   18           3  95825
# 6             19      1193       5   982730936      M    1          10  48073
# 7             24      1193       5   978136709      F   25           7  10023
# 8             28      1193       3   978125194      F   25           1  14607
# 9             33      1193       5   978557765      M   45           3  55421
# 10            39      1193       5   978043535      M   18           4  61820
# ...

# %%
data.ix[0]
# Out:
# user_id                                            1
# movie_id                                        1193
# rating                                             5
# timestamp                                  978300760
# gender                                             F
# age                                                1
# occupation                                        10
# zip                                            48067
# title         One Flew Over the Cuckoo's Nest (1975)
# genres                                         Drama
# Name: 0, dtype: object

# %%
data[data.user_id==1]
# Out:
#        user_id  movie_id  rating  timestamp gender  age  occupation    zip  \
# 0            1      1193       5  978300760      F    1          10  48067
# 1725         1       661       3  978302109      F    1          10  48067
# 2250         1       914       3  978301968      F    1          10  48067
# 2886         1      3408       4  978300275      F    1          10  48067
# 4201         1      2355       5  978824291      F    1          10  48067
# 5904         1      1197       3  978302268      F    1          10  48067
# 8222         1      1287       5  978302039      F    1          10  48067
# 8926         1      2804       5  978300719      F    1          10  48067
# 10278        1       594       4  978302268      F    1          10  48067
# 11041        1       919       4  978301368      F    1          10  48067
# 12759        1       595       5  978824268      F    1          10  48067
# ...

# %% [markdown]
# 按性别计算不同电影的平均分

# %%
mean_ratings=data.pivot_table(values='rating',index='title',columns='gender',aggfunc='mean')
mean_ratings.head(10)
# Out:
# gender                                    F         M
# title
# $1,000,000 Duck (1971)             3.375000  2.761905
# 'Night Mother (1986)               3.388889  3.352941
# 'Til There Was You (1997)          2.675676  2.733333
# 'burbs, The (1989)                 2.793478  2.962085
# ...And Justice for All (1979)      3.828571  3.689024
# 1-900 (1994)                       2.000000  3.000000
# 10 Things I Hate About You (1999)  3.646552  3.311966
# 101 Dalmatians (1961)              3.791444  3.500000
# 101 Dalmatians (1996)              3.240000  2.911215
# 12 Angry Men (1957)                4.184397  4.328421
